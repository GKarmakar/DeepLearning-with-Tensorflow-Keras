# %% [markdown]
# # RNN Classifier

# %%
import keras
from keras.datasets import imdb
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout
from keras.layers import SpatialDropout1D, GlobalMaxPooling1D
from keras.layers import SimpleRNN
from keras.layers import Embedding
from keras.callbacks import ModelCheckpoint
import os
from sklearn.metrics import roc_auc_score
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
output_dir = '/Users/trinakarmakar/anaconda2/model_output/rnn/'

#training hyperparameters
epochs = 16
batch_size = 128

#vector space embedding hyper parameters 
n_dim = 64 
n_unique_words = 10000
max_review_length = 100
pad_type = trunc_type = 'pre' #pad shorter reviews or truncate longer reviews 
drop_emb = 0.2
n_rnn = 256
drop_rnn = 0.2

# %%
(X_train, y_train), (X_valid, y_valid) = imdb.load_data(num_words=n_unique_words)

# %%
X_train = pad_sequences(X_train, maxlen=max_review_length, padding=pad_type, truncating = trunc_type)
X_valid = pad_sequences(X_valid, maxlen=max_review_length, padding=pad_type, truncating = trunc_type)

# %%
model = Sequential()
model.add(Embedding(n_unique_words, n_dim, input_length=max_review_length))
model.add(SpatialDropout1D(drop_emb))
model.add(SimpleRNN(n_rnn, dropout=drop_rnn))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 100, 64)           640000
# _________________________________________________________________
# spatial_dropout1d_5 (Spatial (None, 100, 64)           0
# _________________________________________________________________
# simple_rnn_5 (SimpleRNN)     (None, 256)               82176
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 722,433
# Trainable params: 722,433
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
modelcheckpoint = ModelCheckpoint(filepath=output_dir+"weights.{epoch:02d}.hdf5")

# %%
model.fit(X_train, y_train, batch_size=batch_size, epochs = epochs, verbose=1, validation_data=(X_valid, y_valid), 
          callbacks=[modelcheckpoint])
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/16
# 25000/25000 [==============================] - 88s 4ms/step - loss: 0.7014 - acc: 0.5153 - val_loss: 0.6901 - val_acc: 0.5279
# Epoch 2/16
# 25000/25000 [==============================] - 82s 3ms/step - loss: 0.6892 - acc: 0.5342 - val_loss: 0.6929 - val_acc: 0.5274
# Epoch 3/16
# 25000/25000 [==============================] - 82s 3ms/step - loss: 0.6447 - acc: 0.6178 - val_loss: 0.6376 - val_acc: 0.6202
# Epoch 4/16
# 25000/25000 [==============================] - 84s 3ms/step - loss: 0.5333 - acc: 0.7383 - val_loss: 0.6256 - val_acc: 0.6449
# Epoch 5/16
# 25000/25000 [==============================] - 88s 4ms/step - loss: 0.4603 - acc: 0.7902 - val_loss: 0.4839 - val_acc: 0.7679
# Epoch 6/16
# 25000/25000 [==============================] - 90s 4ms/step - loss: 0.3617 - acc: 0.8465 - val_loss: 0.4191 - val_acc: 0.8191
# Epoch 7/16
# 25000/25000 [==============================] - 100s 4ms/step - loss: 0.3124 - acc: 0.8730 - val_loss: 0.4692 - val_acc: 0.8180
# Epoch 8/16
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.2821 - acc: 0.8882 - val_loss: 0.4320 - val_acc: 0.8108
# Epoch 9/16
# 25000/25000 [==============================] - 97s 4ms/step - loss: 0.2570 - acc: 0.9014 - val_loss: 0.6284 - val_acc: 0.7915
# Epoch 10/16
# 25000/25000 [==============================] - 106s 4ms/step - loss: 0.2646 - acc: 0.8976 - val_loss: 0.4514 - val_acc: 0.8203
# Epoch 11/16
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.3070 - acc: 0.8747 - val_loss: 0.4836 - val_acc: 0.7850
# Epoch 12/16
# 25000/25000 [==============================] - 96s 4ms/step - loss: 0.2409 - acc: 0.9096 - val_loss: 0.4884 - val_acc: 0.8157
# Epoch 13/16
# 25000/25000 [==============================] - 97s 4ms/step - loss: 0.2140 - acc: 0.9214 - val_loss: 0.4751 - val_acc: 0.8054
# Epoch 14/16
# 25000/25000 [==============================] - 99s 4ms/step - loss: 0.1985 - acc: 0.9276 - val_loss: 0.5123 - val_acc: 0.7931
# Epoch 15/16
# 25000/25000 [==============================] - 100s 4ms/step - loss: 0.1975 - acc: 0.9270 - val_loss: 0.5418 - val_acc: 0.8066
# Epoch 16/16
# 25000/25000 [==============================] - 102s 4ms/step - loss: 0.1815 - acc: 0.9354 - val_loss: 0.5261 - val_acc: 0.7949

# %%
model.load_weights(output_dir+'weights.01.hdf5')

# %%
y_hat = model.predict_proba(X_valid)

# %%
plt.hist(y_hat)
_ = plt.axvline(x=0.5, color='orange')

# %%
pct_auc = roc_auc_score(y_valid, y_hat)*100.0

# %%
"{:0.2f}".format(pct_auc)
# Out:
# '54.97'

# %%
float_y_hat = []
for y in y_hat:
    float_y_hat.append(y[0])
ydf = pd.DataFrame(list(zip(float_y_hat, y_valid)), columns=["y_hat", 'y'])

# %%
ydf.head(10)
# Out:
#       y_hat  y
# 0  0.477950  0
# 1  0.444491  1
# 2  0.410370  1
# 3  0.443523  0
# 4  0.487398  1
# 5  0.510960  1
# 6  0.434928  1
# 7  0.424054  0
# 8  0.423901  0
# 9  0.501749  1

# %%
ydf[(ydf.y == 0) & (ydf.y_hat > 0.5)].head(10) #predicted highly negative but in reality it is postive review
# Out:
#        y_hat  y
# 18  0.555008  0
# 26  0.513158  0
# 38  0.536903  0
# 46  0.501972  0
# 59  0.506106  0
# 61  0.519428  0
# 64  0.511011  0
# 79  0.532615  0
# 81  0.516106  0
# 84  0.509060  0

# %%
ydf[(ydf.y == 1) & (ydf.y_hat < 0.5)].head(10) #predicted positive but in reality it is negative review
# Out:
#        y_hat  y
# 1   0.444491  1
# 2   0.410370  1
# 4   0.487398  1
# 6   0.434928  1
# 10  0.459364  1
# 14  0.437488  1
# 16  0.456450  1
# 21  0.468838  1
# 22  0.490706  1
# 24  0.490973  1
